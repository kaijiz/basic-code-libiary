# %%
import matplotlib.pyplot as plt
from pymatgen.io.vasp.outputs import Vasprun
from pymatgen.electronic_structure.plotter import BSPlotter

# Load VASP band structure from vasprun.xml
vasprun = Vasprun("vasprun.xml", parse_projected_eigen=True)
band_structure = vasprun.get_band_structure(line_mode=True)

# Plot using pymatgen's built-in Band Structure Plotter
plotter = BSPlotter(band_structure)
plotter.get_plot()

plt.ylim(-1, 1)

plt.savefig("band.pdf",format='pdf', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# /Users/chengdongwang/anaconda3/envs/dft2/lib/python3.12/site-packages/pymatgen/io/vasp/outputs.py:1260: UserWarning: No POTCAR file with matching TITEL fields was found in
#
#   if potcar := self.get_potcars(path):
# /Users/chengdongwang/anaconda3/envs/dft2/lib/python3.12/site-packages/pymatgen/io/vasp/outputs.py:1278: UserWarning: No POTCAR file with matching TITEL fields was found in
#
#   potcar = self.get_potcars(path)
